# %%
import pygeohash as pgh

geohash = pgh.encode(latitude=55.705, longitude=12.564, precision=12)
display(geohash)

# %%
pgh.get_adjacent(geohash, "right")

# %%
pgh.folium_map(geohash, zoom_start=11).add_geohash("u3buvu", weight=2)#.add_geohash_grid(precision=6)
